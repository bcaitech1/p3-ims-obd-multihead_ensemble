# %%
# !python train.py --transform base
# Out:
# Number of super categories: 11
# Number of categories: 11
# Number of annotations: 21116
# Number of images: 2617
# pytorch version: 1.7.1
# GPU 사용 가능 여부: True
# Tesla P40
# 1
# loading annotations into memory...
# Done (t=5.39s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.99s)
# creating index...
# index created!
# Start training...
# ...
#  44%|███████████████████                        | 19/43 [00:47<00:56,  2.35s/it]
# Epoch [1/10], Step [20/43], Loss: 1.9343, mIoU: 0.0423
#
# ...
#  91%|███████████████████████████████████████    | 39/43 [01:31<00:08,  2.04s/it]
# Epoch [1/10], Step [40/43], Loss: 1.6866, mIoU: 0.0786
#
# ...
# 100%|███████████████████████████████████████████| 43/43 [01:38<00:00,  2.29s/it]
#
#  Start validation step!
#
# ...
# 100%|███████████████████████████████████████████| 10/10 [00:09<00:00,  1.00it/s]
# [Val] epoch 1 | val_loss 1.5129 | val_iou 0.1032
# Best performance at epoch: 1, mIoU: 0.1032
# ...

# %%
# !python train.py --transform train
# Out:
# Number of super categories: 11
# Number of categories: 11
# Number of annotations: 21116
# Number of images: 2617
# pytorch version: 1.7.1
# GPU 사용 가능 여부: True
# Tesla P40
# 1
# loading annotations into memory...
# Done (t=4.13s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.80s)
# creating index...
# index created!
# Start training...
# ...
#  44%|███████████████████                        | 19/43 [05:31<06:52, 17.18s/it]
# Epoch [1/10], Step [20/43], Loss: 1.9065, mIoU: 0.0774
#
# ...
#  91%|███████████████████████████████████████    | 39/43 [11:18<01:08, 17.18s/it]
# Epoch [1/10], Step [40/43], Loss: 1.3830, mIoU: 0.1482
#
# ...
# 100%|███████████████████████████████████████████| 43/43 [12:25<00:00, 17.35s/it]
#
#  Start validation step!
#
# ...
# 100%|███████████████████████████████████████████| 10/10 [02:43<00:00, 16.31s/it]
# [Val] epoch 1 | val_loss 1.2971 | val_iou 0.1529
# Best performance at epoch: 1, mIoU: 0.1529
# ...

# %%
# !python train.py
# Out:
# Number of super categories: 11
# Number of categories: 11
# Number of annotations: 21116
# Number of images: 2617
# pytorch version: 1.7.1
# GPU 사용 가능 여부: True
# Tesla P40
# 1
# loading annotations into memory...
# Done (t=4.33s)
# creating index...
# index created!
# loading annotations into memory...
# ^C
